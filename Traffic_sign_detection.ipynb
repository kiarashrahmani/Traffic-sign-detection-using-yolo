# %% [markdown]
# <a href="https://colab.research.google.com/github/kiarashrahmani/Traffic-sign-detection-using-yolo/blob/main/Traffic_sign_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-198-g34c2187 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.3/78.2 GB disk)

# %% [markdown]
# Mount from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Unzip the files

# %%
# !unzip -q /content/drive/MyDrive/Dataset/Dataset.zip -d ../

# %% [markdown]
# copy our yaml file

# %%
cp /content/drive/MyDrive/Dataset/custom_data.yaml /content/yolov5/data

# %% [markdown]
# # 1. Detect

# %%
# !python detect.py --weights runs/train/exp3/weights/best.pt --img 1000 --conf 0.35 --source /content/drive/MyDrive/Dataset/Test3m.mp4
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp3/weights/best.pt'], source=/content/drive/MyDrive/Dataset/Test3m.mp4, data=data/coco128.yaml, imgsz=[1000, 1000], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-198-g34c2187 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ --img-size [1000, 1000] must be multiple of max stride 32, updating to [1024, 1024]
# video 1/1 (1/2416) /content/drive/MyDrive/Dataset/Test3m.mp4: 576x1024 (no detections), 95.8ms
# video 1/1 (2/2416) /content/drive/MyDrive/Dataset/Test3m.mp4: 576x1024 2 One ways, 14.0ms
# ...

# %% [markdown]
# # 2. Validate

# %%
# Download COCO val
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip  # unzip
# Out:
# 100%|██████████| 780M/780M [00:06<00:00, 135MB/s]

# %%
# Validate YOLOv5s on COCO val
# !python val.py --weights yolov5s.pt --data coco.yaml --img 640 --half
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5s.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v7.0-198-g34c2187 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
# 100% 14.1M/14.1M [00:01<00:00, 8.23MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# val: Scanning /content/datasets/coco/val2017... 4952 images, 48 backgrounds, 0 corrupt: 100% 5000/5000 [00:02<00:00, 1845.93it/s]
# val: New cache created: /content/datasets/coco/val2017.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 157/157 [01:36<00:00,  1.62it/s]
#                    all       5000      36335      0.671      0.519      0.566      0.371
# ...

# %% [markdown]
# # 3. Train

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 1000 --batch 2 --epochs 100 --data custom_data.yaml --weights '' --cfg yolov5s.yaml --cache
# Out:
# train: weights=, cfg=yolov5s.yaml, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=2, imgsz=1000, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-198-g34c2187 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
